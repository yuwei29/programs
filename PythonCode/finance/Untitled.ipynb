# %%
import pandas as pd

# %%
# !pip install pandas_datareader -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ------------------------------------ 109.5/109.5 kB 351.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.9/3.9 MB 5.1 MB/s eta 0:00:00
# ...

# %%
import pandas_datareader as pdr

# %%
import pandas_datareader.data as web

# %%
web.DataReader('^IXIC','yahoo')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 web.DataReader('^IXIC','yahoo')
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:370, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# --> 370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
# ...

# %%
import datetime

# %%
# !pip install quandl -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      -------------------------------------- 52.8/52.8 kB 452.9 kB/s eta 0:00:00
# ...

# %%
import quandl

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              start='2018-03-01', 
              end='2018-04-03')

print(ndq.head(4))
# Out:
#             Index Value     High      Low  Total Market Value  \
# Trade Date
# 2003-01-21      1364.25  1386.71  1364.25        2.002390e+09
# 2003-01-22      1358.23  1379.61  1358.23        1.993347e+09
# 2003-01-23      1393.67  1393.67  1365.11        2.045017e+09
# 2003-01-24      1340.22  1382.35  1340.22        1.966169e+09
#
#             Dividend Market Value
# Trade Date
# 2003-01-21                  302.0
# 2003-01-22                35349.0
# 2003-01-23                25140.0
# 2003-01-24                 1974.0

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              trim_start='2022-01-18', 
              trim_end='2022-02-24')

print(ndq.head(4))
# Out:
# Empty DataFrame
# Columns: [Index Value, High, Low, Total Market Value, Dividend Market Value]
# Index: []

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              trim_start='2018-03-01', 
              trim_end='2018-04-03')

print(ndq.head(4))
# Out:
#             Index Value     High      Low  Total Market Value  \
# Trade Date
# 2018-03-01      7180.56  7307.84  7117.66        1.096433e+13
# 2018-03-02      7257.87  7267.19  7084.83        1.108254e+13
# 2018-03-05      7330.70  7350.07  7205.31        1.119375e+13
# 2018-03-06      7372.01  7378.03  7319.68        1.125703e+13
#
#             Dividend Market Value
# Trade Date
# 2018-03-01           1.412534e+09
# 2018-03-02           5.519555e+08
# 2018-03-05           2.423415e+07
# 2018-03-06           1.519576e+08

# %%
pdr.get_data_yahoo('AAPL')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 pdr.get_data_yahoo('AAPL')
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
# !pip install tushare -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ------------------------------------ 131.1/131.1 kB 552.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 200.9/200.9 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 76.4/76.4 kB ? eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 128.2/128.2 kB 7.9 MB/s eta 0:00:00
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=7da3e496120b144fac798b6257773b70746a3009230db520096b0cb45ef07e02
#   Stored in directory: c:\users\hasee\appdata\local\pip\cache\wheels\3b\fb\fd\c34d8e6cb51eabd4657dff7afb6e4b32196972175a33500555
# Successfully built bs4
# ...

# %%
import tushare as ts

# %%
sh = ts.get_hist_data('sh',start='2022-12-01',end='2022-12-23')
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2

# %%
sh
# Out:
#                open     high    close      low      volume  price_change  \
# date
# 2022-12-23  3038.84  3061.87  3045.87  3031.54  1920203.00         -8.56
# 2022-12-22  3085.80  3096.24  3054.43  3044.60  2236395.25        -13.98
# 2022-12-21  3078.33  3085.80  3068.41  3060.55  1890679.25         -5.36
# 2022-12-20  3098.95  3100.75  3073.77  3061.51  2188367.75        -33.35
# 2022-12-19  3165.31  3170.26  3107.12  3096.10  2785135.50        -60.74
# 2022-12-16  3156.13  3175.35  3167.86  3151.61  2597718.00         -0.79
# 2022-12-15  3177.20  3179.10  3168.65  3158.45  2430233.25         -7.88
# 2022-12-14  3178.55  3189.84  3176.53  3168.59  2656235.75          0.20
# 2022-12-13  3179.44  3187.20  3176.33  3171.48  2858212.00         -2.71
# 2022-12-12  3195.87  3196.72  3179.04  3176.58  3333818.00        -27.91
# 2022-12-09  3197.12  3212.11  3206.95  3182.91  3733432.00          9.60
# 2022-12-08  3196.02  3206.72  3197.35  3187.26  3209693.00         -2.27
# ...

# %%
sz = ts.get_hist_data('sz',start='2022-12-01',end='2022-12-23')
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2

# %%
sz
# Out:
#                 open      high     close       low       volume  price_change  \
# date
# 2022-12-23  10811.57  10918.18  10849.64  10794.14  315967232.0        -26.67
# 2022-12-22  10976.57  11034.67  10876.31  10840.30  347408544.0        -35.78
# 2022-12-21  10966.31  11001.15  10912.09  10872.27  315182784.0        -37.03
# 2022-12-20  11092.86  11092.86  10949.12  10908.53  328218208.0       -175.58
# 2022-12-19  11286.66  11329.56  11124.70  11083.85  400705344.0       -170.33
# 2022-12-16  11289.52  11327.27  11295.03  11234.62  404009952.0        -63.08
# 2022-12-15  11306.79  11371.18  11358.11  11269.61  392689184.0         36.30
# 2022-12-14  11341.96  11375.22  11321.81  11298.43  406111712.0         -1.89
# 2022-12-13  11398.84  11400.01  11323.70  11312.10  409092192.0        -75.43
# 2022-12-12  11453.26  11457.09  11399.13  11392.89  430329024.0       -102.45
# 2022-12-09  11397.10  11511.32  11501.58  11360.15  464345920.0        111.79
# ...

# %%
vix = web.DataReader("VIXCLS", "fred")

# %%
vix
# Out:
#             VIXCLS
# DATE
# 2017-12-25     NaN
# 2017-12-26   10.25
# 2017-12-27   10.47
# 2017-12-28   10.18
# 2017-12-29   11.04
# ...            ...
# 2022-12-16   22.62
# 2022-12-19   22.42
# 2022-12-20   21.48
# 2022-12-21   20.07
# 2022-12-22   21.97
#
# [1304 rows x 1 columns]

# %%
apple = web.DataReader("AAPL", "fred")
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 apple = web.DataReader("AAPL", "fred")
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:449, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     446     return EnigmaReader(dataset_id=name, api_key=api_key).read()
#     448 elif data_source == "fred":
# --> 449     return FredReader(
#     450         symbols=name,
#     451         start=start,
#     452         end=end,
#     453         retry_count=retry_count,
# ...

# %%
aapl = web.DataReader("AAPL", "google")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 aapl = web.DataReader("AAPL", "google")
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:367, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     365 if data_source not in expected_source:
#     366     msg = "data_source=%r is not implemented" % data_source
# --> 367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
# ...

# %%
aapl = web.DataReader("AAPL", "iex")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 aapl = web.DataReader("AAPL", "iex")
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:382, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#    (...)
#     378         session=session,
#     379     ).read()
#     381 elif data_source == "iex":
# --> 382     return IEXDailyReader(
#     383         symbols=name,
# ...

# %%
Nsymbols = web.DataReader("symbols", "nasdaq")

# %%
Nsymbols
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                      Zymeworks Inc. - Common Stock
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
Nsymbols.iloc[1000]
# Out:
# Nasdaq Traded                       True
# Security Name       Acuity Brands, Inc.
# Listing Exchange                       N
# Market Category
# ETF                                False
# Round Lot Size                     100.0
# Test Issue                         False
# Financial Status                     NaN
# CQS Symbol                           AYI
# NASDAQ Symbol                        AYI
# NextShares                         False
# Name: AYI, dtype: object

# %%
import os

# %%
os.environ["IEX_API_KEY"] = "pk_5d88c5513361485f99fbbd6946f7e239"

# %%
aapl = web.DataReader("AAPL", "iex")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File D:\anaconda3\envs\torch180env\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
aapl = web.DataReader("AAPL", "iex")

# %%
aapl
# Out:
#                 open      high       low     close        volume
# date
# 2007-12-28    7.1621    7.1986    7.0314    7.1368  6.996471e+08
# 2007-12-31    7.1339    7.1607    7.0625    7.0743  5.393316e+08
# 2008-01-02    7.1246    7.1521    6.8768    6.9586  1.079177e+09
# 2008-01-03    6.9818    7.0496    6.8818    6.9618  8.420658e+08
# 2008-01-04    6.8375    6.8929    6.3889    6.4304  1.455829e+09
# ...              ...       ...       ...       ...           ...
# 2022-12-19  135.1100  135.2000  131.3200  132.3700  7.959261e+07
# 2022-12-20  131.3900  133.2500  129.8900  132.3000  7.743282e+07
# 2022-12-21  132.9800  136.8100  132.7500  135.4500  8.592799e+07
# 2022-12-22  134.3520  134.5600  130.3000  132.2300  7.785211e+07
# 2022-12-23  130.9200  132.4150  129.6400  131.8600  6.381489e+07
#
# [3780 rows x 5 columns]

# %%
aapl.iloc[3600]
# Out:
# open           171.78
# high           171.78
# low            169.20
# close          170.09
# volume    76575508.00
# Name: 2022-04-08, dtype: float64

# %%
quandl?

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              trim_start='2021-03-01', 
              trim_end='2021-03-10')

print(ndq.head(4))
# Out:
#             Index Value      High       Low  Total Market Value  \
# Trade Date
# 2021-03-01     13588.83  13596.59  13362.66        2.113924e+13
# 2021-03-02     13358.79  13601.33  13352.00        2.078066e+13
# 2021-03-03     12997.75  13372.52  12995.07        2.021937e+13
# 2021-03-04     12723.47  13068.71  12553.96        1.979408e+13
#
#             Dividend Market Value
# Trade Date
# 2021-03-01           9.948729e+06
# 2021-03-02           1.111945e+08
# 2021-03-03           8.198512e+08
# 2021-03-04           1.731269e+09

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              trim_start='2021-12-01', 
              trim_end='2021-12-10')

print(ndq.head(4))
# Out:
# Empty DataFrame
# Columns: [Index Value, High, Low, Total Market Value, Dividend Market Value]
# Index: []

# %%
ndq = quandl.get("NASDAQOMX/COMP-NASDAQ", 
              trim_start='2021-07-01', 
              trim_end='2021-07-10')

print(ndq.head(4))
# Out:
#             Index Value      High       Low  Total Market Value  \
# Trade Date
# 2021-07-01     14522.38  14533.55  14439.40        2.323748e+13
# 2021-07-02     14639.33  14649.11  14555.34        2.342536e+13
# 2021-07-06     14663.64  14687.00  14529.80        2.346265e+13
# 2021-07-07     14665.06  14755.33  14580.79        2.346551e+13
#
#             Dividend Market Value
# Trade Date
# 2021-07-01           3.456905e+07
# 2021-07-02           1.631160e+09
# 2021-07-06           1.151893e+09
# 2021-07-07           1.789125e+07

# %%
web.DataReader('^IXIC','iex')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 web.DataReader('^IXIC','iex')
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\torch180env\lib\site-packages\pandas_datareader\data.py:382, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#    (...)
#     378         session=session,
#     379     ).read()
#     381 elif data_source == "iex":
# --> 382     return IEXDailyReader(
#     383         symbols=name,
#     384         start=start,
# ...
